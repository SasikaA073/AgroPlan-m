# %%
import pandas as pd
import geopandas as gpd

# Load the shapefiles
lk_adm0_shp = gpd.read_file("LK_AGROPLAN/datasets/lk_shp/lka_admbnda_adm0_slsd_20220816.shp") # country
lk_adm1_shp = gpd.read_file("LK_AGROPLAN/datasets/lk_shp/lka_admbnda_adm1_slsd_20220816.shp") # province
lk_adm2_shp = gpd.read_file("LK_AGROPLAN/datasets/lk_shp/lka_admbnda_adm2_slsd_20220816.shp") # district
lk_adm3_shp = gpd.read_file("LK_AGROPLAN/datasets/lk_shp/lka_admbnda_adm3_slsd_20220816.shp") # subdistrict
lk_adm4_shp = gpd.read_file("LK_AGROPLAN/datasets/lk_shp/lka_admbnda_adm4_slsd_20220816.shp") # division
lk_admALL_shp_itos_1 = gpd.read_file("LK_AGROPLAN/datasets/lk_shp/lka_admbndl_admALL_slsd_itos_20220816.shp") # itos 1
lk_admALL_shp_itos_2 = gpd.read_file("LK_AGROPLAN/datasets/lk_shp/lka_admbndp_admALL_slsd_itos_20220816.shp") # itos 2

# %%
# import geopandas as gpd
# import matplotlib.pyplot as plt

# # Load sample data (assuming you have a shapefile or GeoDataFrame)
# # For demonstration, let's use a built-in world dataset from geopandas
# world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# # Create a plot
# fig, ax = plt.subplots(figsize=(12, 8))

# # Plot using various parameters
# world.plot(
#     ax=ax,
#     column='gdp_md_est',  # Column for color-coding
#     cmap='coolwarm',       # Colormap for values in the column
#     legend=True,           # Display legend
#     edgecolor='black',     # Border color of geometries
#     linewidth=0.5,         # Border thickness
#     alpha=0.7,             # Transparency
#     missing_kwds={'color': 'lightgrey', 'label': 'No Data'},  # Handling missing values
#     vmin=1000, vmax=1e7,   # Range for color scaling
#     legend_kwds={
#         'label': "GDP Estimate (Millions USD)",
#         'orientation': "horizontal",  # Customizing legend
#     }
# )

# # Adding a title to the plot
# ax.set_title("World Map: GDP Estimate by Country", fontsize=15)

# # Show the plot
# plt.show()

# %%
lk_adm0_shp.head(2)
# Out:
#      ADM0_EN     ADM0_SI ADM0_TA ADM0_PCODE       date    validOn validTo  \
# 0  Sri Lanka  ශ්‍රී ලංකා  இலங்கை         LK 2022-08-02 2022-08-16     NaT
#
#    Shape_Leng  Shape_Area                                           geometry
# 0   28.119715    5.412464  MULTIPOLYGON (((80.61254 5.92822, 80.61252 5.9...

# %%
import matplotlib.pyplot as plt

# Create subplots (4 rows, 2 columns)
fig, axes = plt.subplots(4, 2, figsize=(14, 18))  # Adjust figure size to fit all plots

# Define a list of shapefiles and titles for each plot
shapefiles = [
    (lk_adm0_shp, "Sri Lanka: ADM0 (Country)"),
    (lk_adm1_shp, "Sri Lanka: ADM1 (Province)"),
    (lk_adm2_shp, "Sri Lanka: ADM2 (District)"),
    (lk_adm3_shp, "Sri Lanka: ADM3 (Subdistrict)"),
    (lk_adm4_shp, "Sri Lanka: ADM4 (Division)"),
    (lk_admALL_shp_itos_1, "Sri Lanka: ADM ALL ITOS 1"),
    (lk_admALL_shp_itos_2, "Sri Lanka: ADM ALL ITOS 2"),  # Uncomment for more layers
]

# Loop through shapefiles and plot them on each subplot
for i, (shapefile, title) in enumerate(shapefiles):
    ax = axes.flatten()[i]  # Get the current subplot
    shapefile.plot(ax=ax, color="beige", edgecolor='black', linewidth=0.3)  # Plot each shapefile
    ax.set_title(title)
    ax.set_axis_off()

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

# %%
lk_adm4_shp.head(2)
# Out:
#    Shape_Leng  Shape_Area           ADM4_EN         ADM4_SI ADM4_TA  \
# 0    0.019689    0.000015  Sammanthranapura  සම්මන්ත්‍රණපුර    None
# 1    0.072878    0.000177      Mattakkuliya     මට්ටක්කුලිය    None
#
#   ADM4_PCODE ADM4_REF  ADM3_EN ADM3_SI   ADM3_TA  ...        ADM1_TA  \
# 0  LK1103005     None  Colombo    කොළඹ  கொழும்பு  ...  மேல் மாகாணம்
# 1  LK1103010     None  Colombo    කොළඹ  கொழும்பு  ...  மேல் மாகாணம்
#
#   ADM1_PCODE    ADM0_EN     ADM0_SI ADM0_TA ADM0_PCODE       date    validOn  \
# 0        LK1  Sri Lanka  ශ්‍රී ලංකා  இலங்கை         LK 2022-08-02 2022-08-16
# 1        LK1  Sri Lanka  ශ්‍රී ලංකා  இலங்கை         LK 2022-08-02 2022-08-16
#
#   validTo                                           geometry
# 0     NaT  POLYGON ((79.8804 6.98093, 79.88032 6.98062, 7...
# 1     NaT  POLYGON ((79.88217 6.97996, 79.88218 6.97995, ...
#
# [2 rows x 27 columns]

# %%
lk_adm4_shp.columns
# Out:
# Index(['Shape_Leng', 'Shape_Area', 'ADM4_EN', 'ADM4_SI', 'ADM4_TA',
#        'ADM4_PCODE', 'ADM4_REF', 'ADM3_EN', 'ADM3_SI', 'ADM3_TA', 'ADM3_PCODE',
#        'ADM2_EN', 'ADM2_SI', 'ADM2_TA', 'ADM2_PCODE', 'ADM1_EN', 'ADM1_SI',
#        'ADM1_TA', 'ADM1_PCODE', 'ADM0_EN', 'ADM0_SI', 'ADM0_TA', 'ADM0_PCODE',
#        'date', 'validOn', 'validTo', 'geometry'],
#       dtype='object')

# %%
lk_adm4_shp.ADM3_PCODE.unique().shape
# Out:
# (339,)

# %%
lk_adm4_shp.ADM4_PCODE.unique().shape
# Out:
# (14043,)

# %%
# Read the CSV file
rainfall_df = pd.read_csv('LK_AGROPLAN/datasets/rainfall_lk.csv')
rainfall_df = rainfall_df.drop(rainfall_df.index[0])
rainfall_df.head()
# Out:
#          date adm2_id ADM2_PCODE n_pixels      rfh  rfh_avg      r1h  r1h_avg  \
# 1  1981-01-01   25840       LK45     41.0  51.9756  38.2098      NaN      NaN
# 2  1981-01-11   25840       LK45     41.0  11.1707  24.2545      NaN      NaN
# 3  1981-01-21   25840       LK45     41.0   2.7073  26.0366  65.8537  88.5008
# 4  1981-02-01   25840       LK45     41.0   14.561  16.4992   28.439  66.7902
# 5  1981-02-11   25840       LK45     41.0      2.0  10.7528  19.2683  53.2886
#
#    r3h r3h_avg       rfq      r1q  r3q version
# 1  NaN     NaN  131.8582      NaN  NaN   final
# 2  NaN     NaN   55.2761      NaN  NaN   final
# 3  NaN     NaN    24.833  77.0082  NaN   final
# 4  NaN     NaN   90.9847  50.0572  NaN   final
# 5  NaN     NaN   44.4364  46.2457  NaN   final

# %%
lk_adm4_shp.ADM3_PCODE.unique()
# Out:
# array(['LK1103', 'LK1106', 'LK1109', 'LK1112', 'LK1115', 'LK1118',
#        'LK1121', 'LK1124', 'LK1127', 'LK1130', 'LK1131', 'LK1133',
#        'LK1136', 'LK1203', 'LK1206', 'LK1209', 'LK1212', 'LK1215',
#        'LK1218', 'LK1221', 'LK1224', 'LK1227', 'LK1230', 'LK1233',
#        'LK1236', 'LK1239', 'LK1303', 'LK1306', 'LK1309', 'LK1310',
#        'LK1312', 'LK1315', 'LK1318', 'LK1321', 'LK1324', 'LK1327',
#        'LK1330', 'LK1333', 'LK1336', 'LK1339', 'LK2103', 'LK2106',
#        'LK2109', 'LK2112', 'LK2115', 'LK2118', 'LK2121', 'LK2124',
#        'LK2127', 'LK2130', 'LK2133', 'LK2134', 'LK2136', 'LK2139',
#        'LK2142', 'LK2145', 'LK2148', 'LK2151', 'LK2154', 'LK2157',
#        'LK2203', 'LK2206', 'LK2209', 'LK2212', 'LK2215', 'LK2218',
#        'LK2221', 'LK2224', 'LK2227', 'LK2230', 'LK2233', 'LK2303',
#        'LK2306', 'LK2309', 'LK2312', 'LK2315', 'LK2318', 'LK2321',
#        'LK2324', 'LK2327', 'LK2330', 'LK3103', 'LK3106', 'LK3109',
# ...

# %%
rainfall_df.date.unique().shape
# Out:
# (1576,)

# %%
# Assuming 'rainfall_df' is your DataFrame and 'date' is a column with date values
date_counts = rainfall_df['date'].value_counts()

# Optionally, sort the counts by date if needed
date_counts = date_counts.sort_index()
date_counts
# Out:
# date
# 1981-01-01    25
# 1981-01-11    25
# 1981-01-21    25
# 1981-02-01    25
# 1981-02-11    25
#               ..
# 2024-08-21    25
# 2024-09-01    25
# 2024-09-11    25
# 2024-09-21    25
# 2024-10-01    25
# Name: count, Length: 1576, dtype: int64

# %%
rainfall_df.adm2_id.unique()
# Out:
# array(['25840', '25833', '25845', '25846', '25847', '25848', '25849',
#        '25850', '25851', '25852', '25853', '25832', '41748', '25842',
#        '25841', '25830', '25839', '25838', '25837', '25836', '25835',
#        '25834', '41749', '25844', '25843'], dtype=object)

# %%
rainfall_df[:100]
# Out:
#            date adm2_id ADM2_PCODE n_pixels      rfh  rfh_avg      r1h  \
# 1    1981-01-01   25840       LK45     41.0  51.9756  38.2098      NaN
# 2    1981-01-11   25840       LK45     41.0  11.1707  24.2545      NaN
# 3    1981-01-21   25840       LK45     41.0   2.7073  26.0366  65.8537
# 4    1981-02-01   25840       LK45     41.0   14.561  16.4992   28.439
# 5    1981-02-11   25840       LK45     41.0      2.0  10.7528  19.2683
# ..          ...     ...        ...      ...      ...      ...      ...
# 96   1983-08-21   25840       LK45     41.0   3.9268   3.3228   4.6829
# 97   1983-09-01   25840       LK45     41.0  14.6829  10.6098  18.9268
# 98   1983-09-11   25840       LK45     41.0  18.9024  10.3195  37.5122
# 99   1983-09-21   25840       LK45     41.0   6.4146  21.6675     40.0
# 100  1983-10-01   25840       LK45     41.0   4.8293   42.461  30.1463
#
#      r1h_avg      r3h  r3h_avg       rfq       r1q       r3q version
# ...

# %%
print(rainfall_df.columns)
# Out:
# Index(['date', 'adm2_id', 'ADM2_PCODE', 'n_pixels', 'rfh', 'rfh_avg', 'r1h',
#        'r1h_avg', 'r3h', 'r3h_avg', 'rfq', 'r1q', 'r3q', 'version'],
#       dtype='object')

# %%
filtered_df = rainfall_df[rainfall_df['date'] == "2024-10-01"]
filtered_df.shape
# Out:
# (25, 14)

# %%
# Merge the rainfall data with the geographic data
merged = lk_adm2_shp.merge(filtered_df, on='ADM2_PCODE')
merged
# Out:
#          ADM2_EN            ADM2_SI            ADM2_TA ADM2_PCODE  \
# 0        Colombo  කොළඹ දිස්ත්‍රික්ක  கொழும்பு மாவட்டம்       LK11
# 1        Gampaha  ගම්පහ දිස්ත්‍රික්    கம்பஹா மாவட்டம்       LK12
# 2       Kalutara  කඵතර දිස්ත්‍රික්ක  களுத்துறை மாவட்டம       LK13
# 3          Kandy  මහනුවර දිස්ත්‍රික     கண்டி மாவட்டம்       LK21
# 4         Matale  මාතලේ දිස්ත්‍රික්   மாத்தளை மாவட்டம்       LK22
# 5   Nuwara Eliya  නුවරඑළිය දිස්ත්‍ර  நுவரேலியா மாவட்டம       LK23
# 6          Galle  ගාල්ල දිස්ත්‍රික්      காலி மாவட்டம்       LK31
# 7         Matara  මාතර දිස්ත්‍රික්ක   மாத்தறை மாவட்டம்       LK32
# 8     Hambantota  හම්බන්තොට දිස්ත්‍  அம்பாந்தோட்டை மாவ       LK33
# 9         Jaffna  යාපනය දිස්ත්‍රික්  யாழ்ப்பாணம் மாவட்       LK41
# 10        Mannar  මන්නාරම දිස්ත්‍රි   மன்னார் மாவட்டம்       LK42
# 11      Vavuniya  වවුනියා දිස්ත්‍රි   வவுனியா மாவட்டம்       LK43
# 12    Mullaitivu  මුලතිවු දිස්ත්‍රි  முல்லைத்தீவு மாவட       LK44
# ...

# %%
merged.head()
# Out:
#     ADM2_EN            ADM2_SI            ADM2_TA ADM2_PCODE  ADM1_EN  \
# 0   Colombo  කොළඹ දිස්ත්‍රික්ක  கொழும்பு மாவட்டம்       LK11  Western
# 1   Gampaha  ගම්පහ දිස්ත්‍රික්    கம்பஹா மாவட்டம்       LK12  Western
# 2  Kalutara  කඵතර දිස්ත්‍රික්ක  களுத்துறை மாவட்டம       LK13  Western
# 3     Kandy  මහනුවර දිස්ත්‍රික     கண்டி மாவட்டம்       LK21  Central
# 4    Matale  මාතලේ දිස්ත්‍රික්   மாத்தளை மாவட்டம்       LK22  Central
#
#          ADM1_SI         ADM1_TA ADM1_PCODE    ADM0_EN     ADM0_SI  ...  \
# 0  බස්නාහිර පළාත   மேல் மாகாணம்         LK1  Sri Lanka  ශ්‍රී ලංකා  ...
# 1  බස්නාහිර පළාත   மேல் மாகாணம்         LK1  Sri Lanka  ශ්‍රී ලංකා  ...
# 2  බස්නාහිර පළාත   மேல் மாகாணம்         LK1  Sri Lanka  ශ්‍රී ලංකා  ...
# 3    මධ්‍යම පළාත  மத்திய மாகாணம்        LK2  Sri Lanka  ශ්‍රී ලංකා  ...
# 4    මධ්‍යම පළාත  மத்திய மாகாணம்        LK2  Sri Lanka  ශ්‍රී ලංකා  ...
#
#         rfh   rfh_avg       r1h   r1h_avg       r3h   r3h_avg       rfq  \
# ...

# %%
merged.rfh.min()
# Out:
# '102.2683'

# %%
merged.rfh.max()
# Out:
# '98.8775'

# %%
# Subset the data to a smaller sample (e.g., first 1000 rows)

# Create the plot
fig, ax = plt.subplots(figsize=(8, 8))  # Increase figure size to 10x10 inches

# subset_merged = merged.sample(1000)
merged.plot(
    ax=ax,
    column='rfh',  # Column for color-coding
    cmap='coolwarm',       # Colormap for values in the column
    # legend=True,           # Display legend
    edgecolor='black',     # Border color of geometries
    linewidth=0.3,         # Border thickness
    alpha=0.7,             # Transparency
    # vmin=merged.rfh.max(), vmax=merged.rfh.min(),   # Range for color scaling
)

plt.title("Rainfall data on 2024-10-11")
plt.show()

# %%
# !python3 --version
# Out:
# Python 3.10.13

# %%
# !pip3 freeze
# Out:
# affine @ file:///Users/ktietz/demo/mc3/conda-bld/affine_1629890479180/work
# altair @ file:///croot/altair_1687526041770/work
# anyio @ file:///croot/anyio_1729121277521/work
# argon2-cffi @ file:///opt/conda/conda-bld/argon2-cffi_1645000214183/work
# argon2-cffi-bindings @ file:///tmp/build/80754af9/argon2-cffi-bindings_1644553347904/work
# asttokens @ file:///opt/conda/conda-bld/asttokens_1646925590279/work
# async-lru @ file:///croot/async-lru_1699554519285/work
# attrs @ file:///croot/attrs_1729089401488/work
# Babel @ file:///croot/babel_1671781930836/work
# beautifulsoup4 @ file:///croot/beautifulsoup4-split_1718029820055/work
# bleach @ file:///opt/conda/conda-bld/bleach_1641577558959/work
# blinker @ file:///croot/blinker_1696539051175/work
# branca @ file:///home/conda/feedstock_root/build_artifacts/branca_1714071803448/work
# Brotli @ file:///home/conda/feedstock_root/build_artifacts/brotli-split_1725267488082/work
# cachetools @ file:///croot/cachetools_1713977085444/work
# ...

# %% [markdown]
# # Solar Data

# %%
# !wget https://cms.solargis.com/file?url=download/Sri%20Lanka/Sri-Lanka_GISdata_LTAy_YearlySum_GlobalSolarAtlas_GEOTIFF.zip
# Out:
# --2024-11-01 15:45:43--  https://cms.solargis.com/file?url=download/Sri%20Lanka/Sri-Lanka_GISdata_LTAy_YearlySum_GlobalSolarAtlas_GEOTIFF.zip
# Resolving cms.solargis.com (cms.solargis.com)... 76.223.11.49, 15.197.129.158, 75.2.43.161, ...
# Connecting to cms.solargis.com (cms.solargis.com)|76.223.11.49|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-11-01 15:45:44 ERROR 404: Not Found.

# %%
# !git lfs install

# %%
# !git clone https://huggingface.co/datasets/SasikaA073/LK_Solar_Dataset

# %%
# prompt: unzip all the zip files in "LK_AGROPLAN/datasets/LK_Solar_Dataset"

import os
import zipfile

def unzip_all_zip_files(directory):
  """Unzips all zip files found within a given directory."""
  for root, _, files in os.walk(directory):
    for file in files:
      if file.endswith(".zip"):
        zip_path = os.path.join(root, file)
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
          zip_ref.extractall(root)
        print(f"Unzipped: {zip_path}")

# Replace 'LK_AGROPLAN/datasets/LK_Solar_Dataset' with your actual directory path
# unzip_all_zip_files("LK_AGROPLAN/datasets/LK_Solar_Dataset")

# %%
# !wget http://download.solargis.com/worldbank/global-PV-potential-studyRASTER-DATA-LAYERSGlobalSolarAtlas-info.zip
# Out:
# --2024-11-01 15:45:45--  http://download.solargis.com/worldbank/global-PV-potential-studyRASTER-DATA-LAYERSGlobalSolarAtlas-info.zip
# Resolving download.solargis.com (download.solargis.com)... 13.225.4.4, 13.225.4.12, 13.225.4.89, ...
# Connecting to download.solargis.com (download.solargis.com)|13.225.4.4|:80... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2024-11-01 15:45:45 ERROR 403: Forbidden.

# %%
import os

tiff_file_paths = []
for root, _, files in os.walk("LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF"):
    for file in files:
        if file.endswith(".tiff") or file.endswith(".tif"):
            tiff_file_paths.append(os.path.join(root, file))

print(tiff_file_paths)
# Out:
# ['LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/DIF.tif', 'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/DNI.tif', 'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/GHI.tif', 'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/GTI.tif', 'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/OPTA.tif', 'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/PVOUT.tif', 'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/TEMP.tif', 'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/monthly/PVOUT_01.tif', 'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTA
# ...

# %%
tiff_file_paths
# Out:
# ['LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/DIF.tif',
#  'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/DNI.tif',
#  'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/GHI.tif',
#  'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/GTI.tif',
#  'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/OPTA.tif',
#  'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/PVOUT.tif',
#  'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/TEMP.tif',
#  'LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/monthly/PVOUT_01.tif',
# ...

# %%
import rasterio
import matplotlib.pyplot as plt

# Replace this with your actual GeoTIFF file path
tiff_file_path = tiff_file_paths[3]

# Open the GeoTIFF file
with rasterio.open(tiff_file_path) as src:
    # Read the data
    data = src.read(1)  # Reading the first band

    # Plotting
    plt.figure(figsize=(10, 10))
    plt.imshow(data, cmap='viridis')  # You can change the colormap as needed
    plt.colorbar(label='Pixel Values')
    plt.title('GeoTIFF Data')
    plt.xlabel('Column')
    plt.ylabel('Row')
    plt.show()

# %%
import rasterio
import matplotlib.pyplot as plt
import geopandas as gpd
from rasterio.plot import show

# Paths to your datasets
tiff_file_path = tiff_file_paths[3]

# Open the GeoTIFF file
with rasterio.open(tiff_file_path) as src:
    # Read the data
    data = src.read(1)  # Read the first band

# Load the rainfall dataset (GeoDataFrame)
rainfall_gdf = merged

# Create the plot
fig, ax = plt.subplots(figsize=(10, 10))  # Adjust size as needed

# Overlay the rainfall data
rainfall_gdf.plot(
    ax=ax,
    column='rfh',  # Column for color-coding in the rainfall dataset
    cmap='coolwarm',  # Colormap for values in the column
    edgecolor='black',  # Border color of geometries
    linewidth=0.3,  # Border thickness
    alpha=0.2,  # Transparency
)

# Plot the GeoTIFF data
show(data, transform=src.transform, ax=ax, cmap='viridis')  # Use `show` from rasterio.plot



# Set the title and labels
plt.title("Rainfall Data Overlayed on GeoTIFF Data")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.colorbar(label='Rainfall Values')  # Add colorbar for rainfall values
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[31], line 39
#      37 plt.xlabel("Longitude")
#      38 plt.ylabel("Latitude")
# ---> 39 plt.colorbar(label='Rainfall Values')  # Add colorbar for rainfall values
#      40 plt.show()
#
# File ~/anaconda3/envs/spark/lib/python3.10/site-packages/matplotlib/pyplot.py:2512, in colorbar(mappable, cax, ax, **kwargs)
#    2510     mappable = gci()
#    2511     if mappable is None:
# -> 2512         raise RuntimeError('No mappable was found to use for colorbar '
#    2513                            'creation. First define a mappable such as '
#    2514                            'an image (with imshow) or a contour set ('
#    2515                            'with contourf).')
#    2516 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2517 return ret
#
# ...

# %%
import rasterio
import matplotlib.pyplot as plt
import geopandas as gpd
from rasterio.plot import show

# Paths to your datasets
tiff_file_path = tiff_file_paths[3]

# Open the GeoTIFF file
with rasterio.open(tiff_file_path) as src:
    # Read the data
    data = src.read(1)  # Read the first band

# Load the rainfall dataset (GeoDataFrame)
rainfall_gdf = merged

# Create the plot
fig, ax = plt.subplots(figsize=(10, 10))  # Adjust size as needed

# Plot the GeoTIFF data
raster_plot = show(data, transform=src.transform, ax=ax, cmap='viridis')

# Overlay the rainfall data
rainfall_plot = rainfall_gdf.plot(
    ax=ax,
    column='rfh',  # Column for color-coding in the rainfall dataset
    cmap='coolwarm',  # Colormap for values in the column
    edgecolor='black',  # Border color of geometries
    linewidth=0.3,  # Border thickness
    alpha=0.7,  # Transparency
)

# Set the title and labels
plt.title("Rainfall Data Overlayed on GeoTIFF Data")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

# Add colorbars for both plots
plt.colorbar(raster_plot, label='GeoTIFF Values', ax=ax, orientation='vertical', pad=0.02)
plt.colorbar(rainfall_plot, label='Rainfall Values', ax=ax, orientation='vertical', pad=0.04)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 39
#      36 plt.ylabel("Latitude")
#      38 # Add colorbars for both plots
# ---> 39 plt.colorbar(raster_plot, label='GeoTIFF Values', ax=ax, orientation='vertical', pad=0.02)
#      40 plt.colorbar(rainfall_plot, label='Rainfall Values', ax=ax, orientation='vertical', pad=0.04)
#      42 plt.show()
#
# File ~/anaconda3/envs/spark/lib/python3.10/site-packages/matplotlib/pyplot.py:2516, in colorbar(mappable, cax, ax, **kwargs)
#    2511     if mappable is None:
#    2512         raise RuntimeError('No mappable was found to use for colorbar '
#    2513                            'creation. First define a mappable such as '
#    2514                            'an image (with imshow) or a contour set ('
#    2515                            'with contourf).')
# ...

# %%
import rasterio
import matplotlib.pyplot as plt
import geopandas as gpd
from rasterio.plot import show

# Paths to your datasets
# tiff_file_path = tiff_file_paths[3]
tiff_file_path = "LK_AGROPLAN/datasets/LK_Solar_Dataset/Sri-Lanka_GISdata_LTAy_AvgDailyTotals_GlobalSolarAtlas-v2_GEOTIFF/GTI.tif"

# Open the GeoTIFF file
with rasterio.open(tiff_file_path) as src:
    # Read the data
    data = src.read(1)  # Read the first band

    # Create the plot
    fig, ax = plt.subplots(figsize=(10, 10))  # Adjust size as needed

    # Plot the GeoTIFF data using imshow instead of show
    raster_plot = ax.imshow(data,
                           extent=[src.bounds.left, src.bounds.right,
                                 src.bounds.bottom, src.bounds.top],
                           cmap='viridis')

    # Overlay the rainfall data
    rainfall_plot = rainfall_gdf.plot(
        ax=ax,
        column='rfh',  # Column for color-coding in the rainfall dataset
        cmap='coolwarm',  # Colormap for values in the column
        edgecolor='black',  # Border color of geometries
        linewidth=0.3,  # Border thickness
        alpha=0.4,  # Transparency
    )

    # Set the title and labels
    plt.title("Rainfall + Solar Irradiance")
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")

    # Add colorbars for both plots
    plt.colorbar(raster_plot, label='GeoTIFF Values', ax=ax, orientation='vertical', pad=0.02)
    plt.colorbar(mappable=rainfall_plot.get_children()[0], label='Rainfall Values', ax=ax, orientation='vertical', pad=0.04)

    plt.show()
